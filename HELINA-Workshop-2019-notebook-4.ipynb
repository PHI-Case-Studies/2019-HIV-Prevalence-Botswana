# %%
# %run resources/library.py

# %%
style_notebook()
# Out:
# <style>
# div.text_cell_render { /* Customize text cells */
#     font-family: 'Arial';
#     font-size:20px;
#     line-height: 1.5em;
#     padding-left:3em;
#     padding-right:3em;
# }
# .CodeMirror {
#     font-family:  'Source Code Pro', monospace;
#     font-size: 18px;
# }
#
# /* Cell output */
#
# .rendered_html pre, .rendered_html code {
#     color: inherit !important;
#     background-color: inherit !important;
# }
# div.output_area pre {
#     line-height: 1.2em;
#     color: #93a1a1 !important;
#     font-family: 'Source Code Pro', monospace;
#     font-size: 16px;
# }
# .rendered_html table, .rendered_html td, .rendered_html th {
#     border: 1px solid #586e75 !important;
#     font-family: 'Arial';
#     font-size: 16px;
# }
# </style>

# %% [markdown]
# ## Welcome to Notebook 4 of the HELINA Workshop

# %% [markdown]
# This notebook will read the pickle files for the UNAIDS data and build trend graphs.

# %% [markdown]
# First, we will read the pickle file for the PLHIV data

# %%
import os
import pandas as pd

# %%
#read the pickle file for PLHIV
PLHIV_df = pd.read_pickle('outputs/PLHIV_df.pkl')

# %%
#examine the dataframe
PLHIV_df
# Out:
#     YEAR  ALLAGEEST  LOWEST   UPEST
# 1   1990      45000   38000   54000
# 2   1991      65000   57000   75000
# 3   1992      90000   80000  100000
# 4   1993     120000  110000  130000
# 5   1994     150000  140000  160000
# 6   1995     180000  170000  190000
# 7   1996     210000  200000  220000
# 8   1997     230000  220000  250000
# 9   1998     260000  240000  270000
# 10  1999     270000  260000  290000
# 11  2000     280000  270000  300000
# 12  2001     290000  270000  310000
# 13  2002     300000  270000  310000
# 14  2003     300000  270000  320000
# 15  2004     300000  270000  320000
# 16  2005     310000  280000  330000
# 17  2006     320000  280000  340000
# 18  2007     320000  290000  340000
# 19  2008     330000  290000  350000
# 20  2009     330000  300000  360000
# 21  2010     340000  300000  360000
# 22  2011     340000  310000  370000
# 23  2012     350000  310000  370000
# 24  2013     350000  320000  380000
# 25  2014     360000  320000  380000
# ...

# %% [markdown]
# Next, we will read the values of the data table columns into variable names that we can plot.

# %%
#assign variables based upon the column names in the dataframe
year = PLHIV_df['YEAR']
all_age_est = PLHIV_df['ALLAGEEST']
all_age_lower_est = PLHIV_df['LOWEST']
all_age_upper_est = PLHIV_df['UPEST']

# %%
#import modules for plotting trend graphs
import matplotlib.pyplot as plt
import matplotlib.transforms as mtrans
import numpy as np

# %%
#plot the trend graph
plt.figure(figsize=(10,7))
plt.plot(year, all_age_est, marker ='o', color ='purple')
plt.plot(year, all_age_lower_est, color ='blue')
plt.plot(year, all_age_upper_est, color ='red')

plt.xlabel('Time (Years)')
plt.ylabel('PLHIV')
plt.title('PLHIV All age Estimate with Upper and Lower bounds, 1990 - 2018')


#plt.legend()
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=3, mode="expand", borderaxespad=0)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# We will now repeat this process for the NEW_INFECTIONS_df.

# %%
#read the pickle file
NEW_INFECTIONS_df = pd.read_pickle('outputs/NEW_INFECTIONS_df.pkl')

# %%
#examine the dataframe
NEW_INFECTIONS_df
# Out:
#     YEAR  ALLAGEEST  LOWEST  UPEST
# 1   1990      16436   14420  18580
# 2   1991      22083   20239  24827
# 3   1992      27294   25504  30509
# 4   1993      32111   30047  35655
# 5   1994      35628   33287  39269
# 6   1995      37145   34359  40953
# 7   1996      36969   33785  40735
# 8   1997      35169   31989  38661
# 9   1998      32749   29462  35506
# 10  1999      29705   26670  31801
# 11  2000      26923   24325  28591
# 12  2001      24430   22388  25811
# 13  2002      22577   21082  23765
# 14  2003      20838   19690  22002
# 15  2004      19348   18228  20542
# 16  2005      17549   16435  18764
# 17  2006      16352   15407  17626
# 18  2007      15576   14449  16821
# 19  2008      15115   13927  16379
# 20  2009      14079   13045  15305
# 21  2010      13384   12349  14482
# 22  2011      12982   11920  13991
# 23  2012      11596   10454  12565
# 24  2013      10706    9470  11774
# 25  2014      10549    9324  11559
# 26  2015      10324    9024  11414
# ...

# %%
# assign variables based upon the column names in the dataframe
year = NEW_INFECTIONS_df['YEAR']
all_age_est = NEW_INFECTIONS_df['ALLAGEEST']
all_age_lower_est = NEW_INFECTIONS_df['LOWEST']
all_age_upper_est = NEW_INFECTIONS_df['UPEST']

# %%
# plot the trend graph
plt.figure(figsize=(10,7))
plt.plot(year, all_age_est, marker ='o', color ='purple')
plt.plot(year, all_age_lower_est, color ='blue')
plt.plot(year, all_age_upper_est, color ='red')

plt.xlabel('Time (Years)')
plt.ylabel('New HIV Infections')
plt.title('New HIV Infections All age Estimate with Upper and Lower bounds, 1990 - 2018')


#plt.legend()
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=3, mode="expand", borderaxespad=0)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# We will now repeat this process for the AIDSDEATHS_df

# %%
#read the pickle file
AIDSDEATHS_df = pd.read_pickle('outputs/AIDSDEATHS_df.pkl')

# %%
#examine the dataframe
AIDSDEATHS_df
# Out:
#     YEAR  ALLAGEEST  LOWEST  UPEST
# 2   1991       1900    1400   2600
# 3   1992       2700    2000   3700
# 4   1993       3700    2800   5200
# 5   1994       5000    3700   6700
# 6   1995       6400    4900   8500
# 7   1996       8100    6100  10000
# 8   1997       9800    7600  12000
# 9   1998      12000    9300  15000
# 10  1999      13000   11000  17000
# 11  2000      15000   13000  18000
# 12  2001      17000   14000  20000
# 13  2002      18000   15000  20000
# 14  2003      17000   15000  19000
# 15  2004      15000   13000  17000
# 16  2005      12000   10000  13000
# 17  2006       9800    8700  11000
# 18  2007       8800    7800   9800
# 19  2008       8300    7400   9200
# 20  2009       7900    7100   8700
# 21  2010       7300    6500   8000
# 22  2011       6900    6200   7700
# 23  2012       6300    5600   7100
# 24  2013       5700    4900   6500
# 25  2014       5300    4500   6100
# 26  2015       5000    4300   5800
# 27  2016       5200    4400   6100
# ...

# %%
# assign variables based upon the column names in the dataframe
year = AIDSDEATHS_df['YEAR']
all_age_est = AIDSDEATHS_df['ALLAGEEST']
all_age_lower_est = AIDSDEATHS_df['LOWEST']
all_age_upper_est = AIDSDEATHS_df['UPEST']

# %%
#plot the trend graph
plt.figure(figsize=(10,7))
plt.plot(year, all_age_est, marker ='o', color ='purple')
plt.plot(year, all_age_lower_est, color ='blue')
plt.plot(year, all_age_upper_est, color ='red')

plt.xlabel('Time (Years)')
plt.ylabel('HIV/AIDS Deaths')
plt.title('HIV/AIDS Deaths All age Estimate with Upper and Lower bounds, 1991 - 2018')


#plt.legend()
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=3, mode="expand", borderaxespad=0)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Congratulations !   You have completed the TIME lego block !

# %% [markdown]
# ![TIME LEGO](resources/Time_Lego_block.png)

# %% [markdown]
# ## Congratulations !  You have now completed the 3 lego blocks (Person, Place, & Time) !

# %% [markdown]
# ![PersonPlaceTime](resources/Person_Place_Time_Lego_blocks.png)

# %% [markdown]
# ## Congratulations !  Now you can build your own case study using these lego blocks !
