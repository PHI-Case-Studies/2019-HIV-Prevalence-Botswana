# %%
# %run resources/library.py

# %%
style_notebook()
# Out:
# <style>
# div.text_cell_render { /* Customize text cells */
#     font-family: 'Arial';
#     font-size:20px;
#     line-height: 1.5em;
#     padding-left:3em;
#     padding-right:3em;
# }
# .CodeMirror {
#     font-family:  'Source Code Pro', monospace;
#     font-size: 18px;
# }
#
# /* Cell output */
#
# .rendered_html pre, .rendered_html code {
#     color: inherit !important;
#     background-color: inherit !important;
# }
# div.output_area pre {
#     line-height: 1.2em;
#     color: #93a1a1 !important;
#     font-family: 'Source Code Pro', monospace;
#     font-size: 16px;
# }
# .rendered_html table, .rendered_html td, .rendered_html th {
#     border: 1px solid #586e75 !important;
#     font-family: 'Arial';
#     font-size: 16px;
# }
# </style>

# %% [markdown]
# ## Welcome to the HELINA Data Science / Jupyter Notebook Workshop 2019 !

# %% [markdown]
# ![cholera map](resources/20040209cholera.jpg)

# %% [markdown]
# Do you recognize this famous map? The Cholera outbreak in London in 1854 forever changed our perspectives on The Cholera outbreak in London in 1854 forever changed our perspectives on the importance of public health, epidemiology, science, and water / waste water management within growing urban cities and rural communities. (There is a GitHub repository for the digital case study about the 1854 Cholera Outbreak [here](https://github.com/PHI-Case-Studies/1854-Cholera-Outbreak-London-Basic).)
#
# The Miasma theory widely believed in 1854 held that "bad air" and "stench" were to blame for the deaths. There was a lot of misinformation and a lack of scientific method within 1854 London. A physician, Dr. John Snow, mapped the deaths and the proximity to water pumps. His systematic approach involved what became known as "shoe-leather epidemiology". He went door-to-door to map the deaths and interview families. He mapped the water sources, pumps used by each household and retraced the steps of the mothers that often gathered the water and washed diapers. There were areas where diapers were washed that were in close proximity to the well for the Broad Street Pump. In addition, London households disposed of waste in their cellars and pits outside the homes, which were also close to the well.
#
# Dr. Snow began to suspect the waste was contaminating the drinking water sources.
#
# Many deaths were proximate to the Broad Street pump. They removed the pump handle.
#
# The outbreak stopped and the modern science of epidemiology was formed.
# Reviewing this outbreak caused us to ask questions: What can we learn from the past (1854) ? How can modern Data Science be informed ?

# %% [markdown]
# Could modern data science tools be used to recreate the past ?  And learn lessons ?
# ![cholera map on jupyter](resources/choleramap_jupyter.png)

# %% [markdown]
# Spoiler alert.....Yes....and...Yes....  But we need to build a foundation of very basic data science skills.
# Epidemiology has many components, but often we speak of Person, Place, and Time.
# Understanding of disease outbreaks and patterns involves description of these 3 facets.¶

# %% [markdown]
#   Today we will strive to build 3 simple components (like puzzle pieces or lego blocks)...

# %% [markdown]
# Using public data sources from Botswana, BAIS 2013 and the Botswana Census 2011, we will explore the epidemiology of disease outbreaks by describing these components and intersections.
# ![Person Place Time Lego Blocks](resources/Person_Place_Time_Lego_blocks.png)

# %% [markdown]
# Today we will build a data science notebook for each of these components. First we will learn how to scrape data from standard sources and build dataframes.
# Then, we will build each component as a separate notebook that is reproducible.

# %% [markdown]
# We will build a PERSON component that will take the form of a Population Pyramid.

# %% [markdown]
# <img src="data:image/png;base64,..." width='700' height='700' style='float:left;'>

# %% [markdown]
# Next, we will build a PLACE component that will take the form of a map.

# %% [markdown]
# <img src="data:image/png;base64,..." width='800' height='800' style='float:left;'>

# %% [markdown]
# We will then build a TIME component that will take the form of a trend graph.

# %% [markdown]
# <img src="data:image/png;base64,..." width='700' height='700' style='float:left;'>

# %% [markdown]
# Excited ?   I hope that you enjoy this workshop, and that it will build both your data science skills and creative confidence. We want you to walk away from this workshop with a new set of skills that you can use in your work for Public Health Informatics !
